# %%
import pandas as pd
import numpy as np
from sklearn.datasets import make_blobs
from sklearn.cluster import DBSCAN,AgglomerativeClustering,KMeans
from sklearn.mixture import GaussianMixture
import seaborn as sns
# %matplotlib inline

# %%
path_datos = "/home/lalo/Documentos/Diplomado Ciencia de Datos/Modulo 3 Modelación no Supervisada/Tablas/"
df = pd.read_excel(path_datos + "Cuestionario Diagnóstico 2019 - 1 (Respuestas).xlsx")
df.head(5)
# Out:
#            Marca temporal                              Carrera  Género  \
# 0 2018-10-17 16:46:19.603  Matemáticas Aplicadas y Computación  Hombre
# 1 2018-10-17 16:52:37.461  Matemáticas Aplicadas y Computación   Mujer
# 2 2018-10-17 16:54:48.531  Matemáticas Aplicadas y Computación  Hombre
# 3 2018-10-17 17:07:29.619  Matemáticas Aplicadas y Computación  Hombre
# 4 2018-10-17 17:26:57.906  Matemáticas Aplicadas y Computación  Hombre
#
#    Edad 🎂       Estado civil ¿Tienes hijos?  \
# 0      18          👤 Soltero             No
# 1      18           💍 Casado             Sí
# 2      18          👤 Soltero             No
# 3      42          👤 Soltero             No
# 4      18  👥 En una relación             No
#
#   ¿Tienes alguna dificultad para? [👓 Ver]  \
# 0                                      Si
# 1                                      Si
# 2                                      No
# 3                                      No
# 4                                      Si
#
# ...

# %%
columnas = df.columns
aux = 1
lst_var_old_names = []
lst_var_new_names = []
for nom_i in columnas:
    New_name = 'Var_' + f'{aux}'
    df = df.rename(columns={nom_i : New_name})
    lst_var_old_names.append(nom_i)
    lst_var_new_names.append(New_name)
    
    aux = aux+1

df.head(5)
# Out:
#                     Var_1                                Var_2   Var_3  Var_4  \
# 0 2018-10-17 16:46:19.603  Matemáticas Aplicadas y Computación  Hombre     18
# 1 2018-10-17 16:52:37.461  Matemáticas Aplicadas y Computación   Mujer     18
# 2 2018-10-17 16:54:48.531  Matemáticas Aplicadas y Computación  Hombre     18
# 3 2018-10-17 17:07:29.619  Matemáticas Aplicadas y Computación  Hombre     42
# 4 2018-10-17 17:26:57.906  Matemáticas Aplicadas y Computación  Hombre     18
#
#                Var_5 Var_6 Var_7 Var_8 Var_9            Var_10  ...   Var_72  \
# 0          👤 Soltero    No    Si    No    No              CDMX  ...  Regular
# 1           💍 Casado    Sí    Si    No    No  Estado de México  ...     Poco
# 2          👤 Soltero    No    No    No    No  Estado de México  ...  Regular
# 3          👤 Soltero    No    No    Si    No  Estado de México  ...  Regular
# 4  👥 En una relación    No    Si    No    No              CDMX  ...  Regular
#
# ...
